# %% [markdown]
# # Tutorial 3
#
# In this notebook, we will see how to pass your own encoder and decoder's architectures to your VAE model using pyraug! This is an illustraion of the section ``Making yor own autoencoder mdoel`` of the documentation.

# %%
import torch
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Get the data

# %%
cifar_trainset = datasets.CIFAR10(root='../data', train=True, download=True, transform=None)
n_samples = 200
_dataset_to_augment = cifar_trainset.data[np.array(cifar_trainset.targets)==2][:n_samples]
# Out:
# Files already downloaded and verified

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
for i in range(10):
        for j in range(10):
                axes[i][j].matshow(_dataset_to_augment[i*10 +j].reshape(32, 32, 3), cmap='gray')
                axes[i][j].axis('off')

plt.tight_layout(pad=0.8)

# %% [markdown]
# ## Let's build a custom auto-encoding architecture!

# %% [markdown]
# ### First thing, you need to import the ``BaseEncoder`` and ``BaseDecoder`` classes from pyraug by running

# %%
from pyraug.models.nn import BaseEncoder, BaseDecoder

# %% [markdown]
# ### Then build your own architectures

# %%
import torch.nn as nn

class Encoder_Conv(BaseEncoder):
    def __init__(self, args):
        BaseEncoder.__init__(self)
        self.latent_dim = args.latent_dim
        self.n_channels = 3

        self.layers = nn.Sequential(
            nn.Conv2d(
                self.n_channels, out_channels=32, kernel_size=3, stride=2, padding=1
            ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, out_channels=32, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, out_channels=32, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
        )

        self.fc1 = nn.Sequential(nn.Linear(512, 400), nn.ReLU())

        self.mu = nn.Linear(400, self.latent_dim)
        self.std = nn.Linear(400, self.latent_dim)

    def forward(self, x):
        out = self.layers(
            x.reshape(
                -1, self.n_channels, 32, 32
                )
            )
        out = self.fc1(out.reshape(x.shape[0], -1))
        return self.mu(out), self.std(out)


class Decoder_Conv(BaseDecoder):
    def __init__(self, args):
        BaseDecoder.__init__(self)

        self.latent_dim = args.latent_dim
        self.n_channels = 3

        self.fc1 = nn.Sequential(
            nn.Linear(self.latent_dim, 400), nn.ReLU(), nn.Linear(400, 512), nn.ReLU()
        )

        self.layers = nn.Sequential(
            nn.ConvTranspose2d(
                32,
                out_channels=32,
                kernel_size=3,
                stride=2,
                padding=1
            ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.ConvTranspose2d(
                32,
                out_channels=32,
                kernel_size=3,
                stride=2,
                padding=0,
                output_padding=1,
            ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.ConvTranspose2d(
                32,
                out_channels=self.n_channels,
                kernel_size=3,
                stride=2,
                padding=1,
                output_padding=1,
            ),
            nn.BatchNorm2d(self.n_channels),
            nn.Sigmoid(),
        )

    def forward(self, z):
        out = self.fc1(z)
        out = self.layers(out.reshape(z.shape[0], 32, 4, 4))
        return out.reshape(z.shape[0], -1)

# %% [markdown]
# ### Define a model configuration (in which the latent will be stated). Here, we use the RHVAE model.

# %%
from pyraug.models.rhvae import RHVAEConfig

model_config = RHVAEConfig(
    input_dim=3*32*32, # This is needed since will use a predefined metric network that requires the input dim to be                           # built automatically
    latent_dim=10
    )

# %% [markdown]
# ### Build your encoder and decoder

# %%
encoder = Encoder_Conv(model_config)
decoder= Decoder_Conv(model_config)

# %% [markdown]
# ### Last but not least. Build you RHVAE model by passing the ``encoder`` and ``decoder`` arguments

# %%
from pyraug.models import RHVAE

model = RHVAE(
    model_config=model_config,
    encoder=encoder,
    decoder=decoder
)

# %% [markdown]
# ### Now you can see the model that you've just built contains the custom autoencoder and decoder

# %%
model
# Out:
# RHVAE(
#   (encoder): Encoder_Conv(
#     (layers): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#     )
#     (fc1): Sequential(
#       (0): Linear(in_features=512, out_features=400, bias=True)
#       (1): ReLU()
#     )
#     (mu): Linear(in_features=400, out_features=10, bias=True)
#     (std): Linear(in_features=400, out_features=10, bias=True)
#   )
#   (decoder): Decoder_Conv(
#     (fc1): Sequential(
#       (0): Linear(in_features=10, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=512, bias=True)
#       (3): ReLU()
#     )
#     (layers): Sequential(
#       (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): Sigmoid()
#     )
#   )
#   (metric): Metric_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=3072, out_features=400, bias=True)
#       (1): ReLU()
#     )
#     (diag): Linear(in_features=400, out_features=10, bias=True)
#     (lower): Linear(in_features=400, out_features=45, bias=True)
#   )
# )

# %% [markdown]
# ### *note*: If you want to launch a training of such a model, try to ensure that the provided architectures are suited for the data. pyraug performs a model sanity check before launching training and raises an error if the model cannot encode and decode an input data point

# %% [markdown]
# ## Train the model !

# %% [markdown]
# ### Likewise tutorial 1, you can now trained you model.

# %%
from pyraug.trainers.training_config import TrainingConfig
from pyraug.pipelines import TrainingPipeline

# %% [markdown]
# ### Build the training pipeline with your ``TrainingConfig`` instance

# %%
training_config = TrainingConfig(
    output_dir='my_model_with_custom_archi',
    no_cuda=False,
    learning_rate=1e-3,
    batch_size=200,
    train_early_stopping=100,
    steps_saving=0,
    max_epochs=20000)

# %%
torch.manual_seed(8)
pipeline = TrainingPipeline(
    data_loader=None,
    data_processor=None,
    model=model,
    optimizer=None,
    training_config=training_config)

# %% [markdown]
# ### Launch the ``Pipeline``

# %%
# set channel first
dataset_to_augment = np.transpose(_dataset_to_augment, (0, 3, 2, 1))

pipeline(
    train_data=dataset_to_augment,
    log_output_dir='output_logs'
)
# Out:
# Data normalized using individual_min_max_scaling.
#  -> If this is not the desired behavior pass an instance of DataProcess with 'data_normalization_type' attribute set to desired normalization or None
# Created my_model_with_custom_archi folder since did not exist.
# Model passed sanity check !
#
# Created my_model_with_custom_archi/training_2021-06-28_17-58-25.
# Training config, checkpoints and final model will be saved here.
#
# Created output_logs folder since did not exists. Training logs will be recodered here.
#
# Successfully launched training !
# Saved checkpoint at epoch 1000
# Saved checkpoint at epoch 2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4f351a8f7244> in <module>
#       2 dataset_to_augment = np.transpose(_dataset_to_augment, (0, 3, 2, 1))
#       3
# ----> 4 pipeline(
#       5     train_data=dataset_to_augment,
#       6     log_output_dir='output_logs'
#
# ~/Documents/pyraug/src/pyraug/pipelines/training.py in __call__(self, train_data, eval_data, log_output_dir)
#     175         self.trainer = trainer
#     176
# --> 177         trainer.train(log_output_dir=log_output_dir)
#
# ~/Documents/pyraug/src/pyraug/trainers/trainers.py in train(self, log_output_dir)
#     283         for epoch in range(1, self.training_config.max_epochs):
#     284
# --> 285             epoch_train_loss = self.train_step()
#     286
#     287
#
# ~/Documents/pyraug/src/pyraug/trainers/trainers.py in train_step(self)
#     425             self.optimizer.zero_grad()
#     426
# --> 427             model_output = self.model(inputs)
#     428
#     429             loss = model_output.loss
#
# ~/anaconda3/envs/pyraug/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Documents/pyraug/src/pyraug/models/rhvae/rhvae_model.py in forward(self, inputs)
#     189
#     190             # step 2
# --> 191             z = self._leap_step_2(recon_x, x, z, rho_, G_inv, G_log_det)
#     192
#     193             recon_x = self.decoder(z)
#
# ~/Documents/pyraug/src/pyraug/models/rhvae/rhvae_model.py in _leap_step_2(self, recon_x, x, z, rho, G_inv, G_log_det, steps)
#     397         using fixed point iterations
#     398         """
# --> 399         H0 = self._hamiltonian(recon_x, x, z, rho, G_inv, G_log_det)
#     400         grho_0 = grad(H0, rho)[0]
#     401
#
# ~/Documents/pyraug/src/pyraug/models/rhvae/rhvae_model.py in _hamiltonian(self, recon_x, x, z, rho, G_inv, G_log_det)
#     427         ).sum()
#     428
# --> 429         return -self._log_p_xz(recon_x, x, z).sum() + 0.5 * norm + 0.5 * G_log_det.sum()
#     430
#     431     def update_metric(self):
#
# ~/Documents/pyraug/src/pyraug/models/rhvae/rhvae_model.py in _log_p_xz(self, recon_x, x, z)
#     548         """
#     549         logpxz = self._log_p_x_given_z(recon_x, x)
# --> 550         logpz = self._log_z(z)
#     551         return logpxz + logpz
#     552
#
# ~/Documents/pyraug/src/pyraug/models/rhvae/rhvae_model.py in _log_z(self, z)
#     537
#     538         # define a N(0, I) distribution
# --> 539         normal = torch.distributions.MultivariateNormal(
#     540             loc=torch.zeros(self.latent_dim).to(z.device),
#     541             covariance_matrix=torch.eye(self.latent_dim).to(z.device),
#
# ~/anaconda3/envs/pyraug/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py in __init__(self, loc, covariance_matrix, precision_matrix, scale_tril, validate_args)
#     144
#     145         event_shape = self.loc.shape[-1:]
# --> 146         super(MultivariateNormal, self).__init__(batch_shape, event_shape, validate_args=validate_args)
#     147
#     148         if scale_tril is not None:
#
# ~/anaconda3/envs/pyraug/lib/python3.8/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      50                 if param not in self.__dict__ and isinstance(getattr(type(self), param), lazy_property):
#      51                     continue  # skip checking lazily-constructed args
# ---> 52                 if not constraint.check(getattr(self, param)).all():
#      53                     raise ValueError("The parameter {} has invalid values".format(param))
#      54         super(Distribution, self).__init__()
#
# KeyboardInterrupt:

# %% [markdown]
# ### *note 1*: You will see now that a ``encoder.pkl`` and ``decoder.pkl`` appear in the folder ``my_model_with_custom_archi/trainin_YYYY_MM_DD_hh_mm_ss/final_model`` to allow model rebuilding with your own architecture ``Encoder_Conv`` and ``Decoder_Conv``.
#
# ### *note 2*: Model rebuilding is based on the [dill](https://pypi.org/project/dill/) librairy allowing to reload the class whithout importing them. Hence, you should still be able to reload the model even if the classes ``Encoder_Conv`` or ``Decoder_Conv`` were not imported.

# %% [markdown]
# ### You can now reload the model easily using the classmethod ``RHVAE.load_from_folder``

# %%
last_training = sorted(os.listdir('my_model_with_custom_archi'))[-1]
print(last_training)
# Out:
# training_2021-06-28_17-58-25

# %%
model_rec = RHVAE.load_from_folder(os.path.join('my_model_with_custom_archi', last_training, 'checkpoint_epoch_2000'))
model_rec
# Out:
# RHVAE(
#   (encoder): Encoder_Conv(
#     (layers): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#     )
#     (fc1): Sequential(
#       (0): Linear(in_features=512, out_features=400, bias=True)
#       (1): ReLU()
#     )
#     (mu): Linear(in_features=400, out_features=10, bias=True)
#     (std): Linear(in_features=400, out_features=10, bias=True)
#   )
#   (decoder): Decoder_Conv(
#     (fc1): Sequential(
#       (0): Linear(in_features=10, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=512, bias=True)
#       (3): ReLU()
#     )
#     (layers): Sequential(
#       (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): Sigmoid()
#     )
#   )
#   (metric): Metric_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=3072, out_features=400, bias=True)
#       (1): ReLU()
#     )
#     (diag): Linear(in_features=400, out_features=10, bias=True)
#     (lower): Linear(in_features=400, out_features=45, bias=True)
#   )
# )

# %% [markdown]
# ## Likewise tutorial 1, the model can then be used to generate new samples !

# %%
from pyraug.models.rhvae import RHVAESamplerConfig
from pyraug.models.rhvae.rhvae_sampler import RHVAESampler

sampler_config = RHVAESamplerConfig(
        output_dir='my_generated_data_with_custom_archi',
        mcmc_steps_nbr=100,
        batch_size=100,
        no_cuda=False
        )

sampler = RHVAESampler(
    model=model_rec,
    sampler_config=sampler_config
)
# Out:
# Created my_generated_data_with_custom_archi folder since did not exist.

# %%
from pyraug.pipelines import GenerationPipeline

generation_pipe = GenerationPipeline(
    model=model,
    sampler=sampler
)

# %%
generation_pipe(100)
# Out:
# Created my_generated_data_with_custom_archi/generation_2021-06-28_18-06-07.Generated data and sampler config will be saved here.
#
# Generation successfully launched !

# %%
last_generation = sorted(os.listdir('my_generated_data_with_custom_archi'))[-1]

# %%
generated_data = torch.load(os.path.join('my_generated_data_with_custom_archi', last_generation, 'generated_data_100_0.pt'))

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
im_n = 0
for i in range(10):
    for j in range(10):
                axes[i][j].matshow(np.transpose(generated_data[i*10 +j].cpu().reshape(3, 32, 32), (2, 1,0)) , cmap='gray')
                axes[i][j].axis('off')

plt.tight_layout(pad=0.8)
